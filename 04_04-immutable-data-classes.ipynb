# %%
from dataclasses import dataclass

# %% [markdown]
# # Creating immutable data classes

# %%
@dataclass(frozen=True)  
# "The "frozen" parameter makes the class immutable
class ImmutableClass:
    value1: str = "Value 1"
    value2: int = 0

    def somefunc(self, newval):
        self.value2 = newval

# %%
obj = ImmutableClass()
print(obj)
# Out:
# ImmutableClass(value1='Value 1', value2=0)

# %%
# The values can be initialized also, but not subsequently changed
obj2 = ImmutableClass("Another Value", 15)
print(obj2)
# Out:
# ImmutableClass(value1='Another Value', value2=15)

# %%
# attempting to change the value of an immutable class throws an exception
obj.value1 = "Another value"
print(obj.value1)
# Out:
# ---------------------------------------------------------------------------
# FrozenInstanceError                       Traceback (most recent call last)
# Cell In[6], line 2
#       1 # attempting to change the value of an immutable class throws an exception
# ----> 2 obj.value1 = "Another value"
#       3 print(obj.value1)
#
# File <string>:16, in __setattr__(self, name, value)
#
# FrozenInstanceError: cannot assign to field 'value1'

# %%
# Frozen classes can't modify themselves either
obj.somefunc(20)
# Out:
# ---------------------------------------------------------------------------
# FrozenInstanceError                       Traceback (most recent call last)
# Cell In[7], line 2
#       1 # Frozen classes can't modify themselves either
# ----> 2 obj.somefunc(20)
#
# Cell In[2], line 8, in ImmutableClass.somefunc(self, newval)
#       7 def somefunc(self, newval):
# ----> 8     self.value2 = newval
#
# File <string>:16, in __setattr__(self, name, value)
#
# FrozenInstanceError: cannot assign to field 'value2'
